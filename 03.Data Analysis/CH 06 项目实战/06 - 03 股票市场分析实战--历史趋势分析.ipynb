# %%
# 基本信息
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# 股票数据的读取
import pandas_datareader as pdr

# 可视化
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# time
from datetime import datetime

# %% [markdown]
# # 读取信息

# %%
start = datetime(2020,9,20)
alibaba = pdr.get_data_yahoo('BABA', start = start)
amazon = pdr.get_data_yahoo('AMZN', start = start)

# %%
alibaba.to_csv('BABA.csv')
amazon.to_csv('AMZN.csv')

# %%
alibaba.head()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2020-09-21  274.220001  266.399994  269.100006  273.820007   9076400
# 2020-09-22  276.320007  270.049988  276.019989  275.290009   9673300
# 2020-09-23  277.829987  271.500000  275.399994  272.950012   7353200
# 2020-09-24  271.250000  267.334015  267.929993  269.730011   9562100
# 2020-09-25  271.809998  264.559998  267.570007  271.089996  11466600
#
#              Adj Close
# Date
# 2020-09-21  273.820007
# 2020-09-22  275.290009
# 2020-09-23  272.950012
# 2020-09-24  269.730011
# 2020-09-25  271.089996

# %% [markdown]
# # 交易量分析

# %%
alibaba['Adj Close'].plot(legend=True)

# %%
alibaba['Volume'].plot(legend=True)

# %%
alibaba['Adj Close'].plot()
amazon['Adj Close'].plot()

# %% [markdown]
# # 变化分析

# %%
# 原始数据
alibaba.head()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2020-09-21  274.220001  266.399994  269.100006  273.820007   9076400
# 2020-09-22  276.320007  270.049988  276.019989  275.290009   9673300
# 2020-09-23  277.829987  271.500000  275.399994  272.950012   7353200
# 2020-09-24  271.250000  267.334015  267.929993  269.730011   9562100
# 2020-09-25  271.809998  264.559998  267.570007  271.089996  11466600
#
#              Adj Close
# Date
# 2020-09-21  273.820007
# 2020-09-22  275.290009
# 2020-09-23  272.950012
# 2020-09-24  269.730011
# 2020-09-25  271.089996

# %%
# 每天最高值与最低值之间的差值
alibaba['high-low'] = alibaba['High'] - alibaba['Low']

# %%
alibaba.head()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2020-09-21  274.220001  266.399994  269.100006  273.820007   9076400
# 2020-09-22  276.320007  270.049988  276.019989  275.290009   9673300
# 2020-09-23  277.829987  271.500000  275.399994  272.950012   7353200
# 2020-09-24  271.250000  267.334015  267.929993  269.730011   9562100
# 2020-09-25  271.809998  264.559998  267.570007  271.089996  11466600
#
#              Adj Close  high-low
# Date
# 2020-09-21  273.820007  7.820007
# 2020-09-22  275.290009  6.270020
# 2020-09-23  272.950012  6.329987
# 2020-09-24  269.730011  3.915985
# 2020-09-25  271.089996  7.250000

# %%
alibaba['high-low'].plot()

# %% [markdown]
# # pct_change():
# Percentage change between the current and a prior element.

# %%
# daily return 每日变化
alibaba['daily-return'] = alibaba['Adj Close'].pct_change()

# %% [markdown]
# ## plot() 参数 marker: 设置顶点图样

# %%
alibaba['daily-return'].plot(figsize=(10,4),linestyle='--',marker='o')

# %%
alibaba['daily-return'].plot(kind='hist')

# %% [markdown]
# ## dropna() ： 省略 NaN 值

# %%
sns.distplot(alibaba['daily-return'].dropna(),bins=100,color='purple')
